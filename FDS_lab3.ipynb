# %% [markdown]
# <a href="https://colab.research.google.com/github/d12eek/Data-Science/blob/main/FDS_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gaussian Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-10000, 10000, 1000)
# Mean = 0, SD = 2.
plt.plot(x_axis, norm.pdf(x_axis,49.6,9.9))
plt.show()

# %% [markdown]
# # **Uniform Distribution**

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
population = np.random.normal(loc=50, scale=10, size= 10000)

def uniform_sample(population, sample_size):
  indices = np.random.choice(len(population), sample_size, replace=False)
  sample = [population[i] for i in indices]
  return sample

sample_size = 100
sample = uniform_sample(population, sample_size)

sample
# Out:
# [51.89045825445978,
#  38.65272327857251,
#  54.74807691555373,
#  75.1752908808016,
#  46.39873925210727,
#  53.47898588277339,
#  20.02514901805788,
#  53.097270856605455,
#  45.15673666286029,
#  59.46148716036264,
#  53.032670118186154,
#  64.58552083903365,
#  49.56791620037668,
#  59.09552527100909,
#  52.246271381773845,
#  56.343497901182104,
#  63.68804899549441,
#  69.44568870424283,
#  39.41607016351886,
#  30.895310775482738,
#  42.70895709083933,
#  60.06928322678304,
#  38.42360714086182,
#  56.001318062487975,
#  55.97685876902822,
#  49.972347257888,
#  40.1874105703862,
#  48.0132162570874,
#  43.289252472221655,
#  50.90824635028752,
#  57.25274329434321,
#  50.67374838447351,
#  56.60925634129567,
#  50.55486586149362,
#  37.40217826208316,
#  52.41909036551217,
#  50.648417783031654,
#  29.12370311772049,
#  39.53259927205404,
#  64.70177427329656,
#  64.45380039614139,
#  62.51855197803126,
#  40.84060016146867,
#  43.62220134984111,
#  53.289082819438484,
# ...

# %%
sample_mean= np.mean(sample)
sample_mean
# Out:
# 49.612587767950274

# %%
sample_std= np.std(sample, ddof=1) #ddof is degree of freedom
sample_std
# Out:
# 9.97967822232533

# %%
plt.hist(sample)
# Out:
# (array([ 2.,  4.,  2., 11., 22., 22., 19., 12.,  5.,  1.]),
#  array([20.02514902, 25.5401632 , 31.05517739, 36.57019158, 42.08520576,
#         47.60021995, 53.11523414, 58.63024832, 64.14526251, 69.66027669,
#         75.17529088]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(sample)

# %%
plt.plot(sample)

# %%
# Confidence Interval for mean
confidence_level = 0.95
alpha = 1-confidence_level
t_critical = stats.t.ppf(1-alpha/2, df=sample_size-1) #t critical value is t value from t table using alpha
margin_of_error= t_critical* (sample_std / np.sqrt(sample_size))

#confidence Interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print(f"Sample Mean: {sample_mean: .2f}")
print(f"Sample Standard Deviation: {sample_std: .2f}")
print(f"{confidence_level * 100: .0f} % Confidence Interval for Mean: {confidence_interval}")

#Hypothesis Testing (one-sample t-test)
#Null Hypothesis: mean of the population is 50
hypothesis_mean = 50
t_statistic, p_value = stats.ttest_1samp(sample, hypothesis_mean)
print(f"T-Statistic: {t_statistic: .2f}")
print(f"P-value: {p_value: .4f}")
# Out:
# Sample Mean:  49.61
# Sample Standard Deviation:  9.98
#  95 % Confidence Interval for Mean: (47.632403098016276, 51.59277243788427)
# T-Statistic: -0.39
# P-value:  0.6987

# %%
# Decision based on p-value :
if p_value < alpha:
  print(f"Reject the null hypothesis : The sample mean significantly differs from {hypothesis_mean:.2f}")
else:
  print(f"Failed to reject the null hypothesis : The sample mean does not significantly differs from hypothesis mean")
# Out:
# Failed to reject the null hypothesis : The sample mean does not significantly differs from hypothesis mean
