# %% [markdown]
# <a href="https://colab.research.google.com/github/d12eek/Data-Science/blob/main/Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task - Design and Gradient Descent Algorithm
# Step 1 : y = 3x + 0.7
# Step 2 : Design Gradient Descent Function

import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
# Learning Rate => alpha = 0.01

# Step A) Generate a data of size = 30 inrange of 1-50
x = np.random.randint(1,50,30)
y = 3*x + 0.7

# Step B) Convert this into a dataframe
df = pd.DataFrame({'x':x,'y':y})
df.head()
# Out:
#     x      y
# 0  42  126.7
# 1  34  102.7
# 2   1    3.7
# 3  19   57.7
# 4  40  120.7

# %%
# Step C) C (1): Let a hypothetical equation be y' = Wx + b -> Let W = 5 and b = 1
#          C (2): Make a function to calculate y' and append it to the df

W0 = 5
b0 = 1
y_pred = W0*x + b0
df['y_pred'] = y_pred
df.head()
# Out:
#     x      y  y_pred
# 0  42  126.7     211
# 1  34  102.7     171
# 2   1    3.7       6
# 3  19   57.7      96
# 4  40  120.7     201

# %%
# Step D) Calculating Errors = y-y_pred
df['error'] = df['y'] - df['y_pred']
df.head()
# Out:
#     x      y  y_pred  error
# 0  42  126.7     211  -84.3
# 1  34  102.7     171  -68.3
# 2   1    3.7       6   -2.3
# 3  19   57.7      96  -38.3
# 4  40  120.7     201  -80.3

# %%
df.drop(['y_pred','error'],axis=1,inplace=True)
df.head()
# Out:
#     x      y
# 0  42  126.7
# 1  34  102.7
# 2   1    3.7
# 3  19   57.7
# 4  40  120.7

# %%
# # Assumed value of W and b :
# W0 = 5
# b0 = 1
# alpha = 0.01

# %%
# def update_val(x,y_real,W0,b0,alpha):
#     y_pred = W0*x + b0
#     print(y_pred)
#     error = np.mean((y_real - y_pred)**2)
#     print(error)
#     W0 = W0 - (alpha/30)*error*x
#     print(W0)
#     b0 = b0 - (alpha/30)*error
#     print(b0)
#     return W0,b0

# %%
# W0 = 5
# b0 = 1
# alpha = 0.01

# print("Old W0 and b0 values = {0} and {1}".format(W0,b0))

# for i in range(30):
#     W0,b0 = update_val(df['x'][i],df['y'][i],W0,b0,alpha)

# print("New W0 and b0 values = {0} and {1}".format(W0,b0))

# %%
df.head()
# Out:
#     x      y
# 0  42  126.7
# 1  34  102.7
# 2   1    3.7
# 3  19   57.7
# 4  40  120.7

# %%
# # df['x']
# for i in range(30):
#   print(df['x'][i])

# for i in range(30):
#   print(df['y'][i])

# %%
# df['y_cal'] = 5*df['x']+1

# %%
# def update(w,b,x,y,al):
#   # print("x = ",x)
#   # print("y = ",y)
#   # print("w = ",w)
#   # print("b = ",b)
#   # print("al = ",al)
#   # E = y-y_cal
#   y_cal = w*x + b
#   E = y-y_cal
#   # print("E = ",E)
#   # Grad 1 : al*E*x and Grad 2 : al*E
#   w = w-(al*E*x)
#   b = b-(al*E)
#   return w,b

# wo=5
# bo=1
# print("Old value of wo and bo : ",wo,bo)
# for i in range(30):
#   wo,bo = update(wo,bo,df['x'][i],df['y'][i],0.01)
#   print("New value of wo and bo : ",wo,bo)

# print("New value of wo and bo : ",wo,bo)

# %%
def update(w, b, x, y, al):
    # Calculate y_cal (predicted value)
    y_cal = w * x + b
    # Calculate the error
    E = y - y_cal
    # Update w and b using gradient descent
    w = w - (al * E * x)
    b = b - (al * E)
    return w, b

wo = 5
bo = 1
print("Old value of wo and bo: ", wo, bo)

for i in range(30):
    wo, bo = update(wo, bo, df['x'][i], df['y'][i], 0.00001)
    print("New value of wo and bo: ", wo, bo)

print("New value of wo and bo: ", wo, bo)
# Out:
# Old value of wo and bo:  5 1
# New value of wo and bo:  5.035406 1.000843
# New value of wo and bo:  5.05903757998 1.0015380464699999
# New value of wo and bo:  5.059061185736264 1.0015616522262645
# New value of wo and bo:  5.0665516933306955 1.0019558894680767
# New value of wo and bo:  5.099737302779774 1.0027855297043036
# New value of wo and bo:  5.106594953036127 1.003166510274101
# New value of wo and bo:  5.123195544090807 1.0037593885260538
# New value of wo and bo:  5.128679526185843 1.0041021374069936
# New value of wo and bo:  5.13083861592577 1.0043180463809862
# New value of wo and bo:  5.142180745354684 1.004811182443113
# New value of wo and bo:  5.152615958622339 1.0052855103189153
# New value of wo and bo:  5.170807991632345 1.005912821802019
# New value of wo and bo:  5.2056632846271835 1.00678420412689
# New value of wo and bo:  5.213684018083471 1.0072063479930105
# New value of wo and bo:  5.219400202185444 1.0075636094993838
# New value of wo and bo:  5.248274351705187 1.0083656692082656
# New value of wo and bo:  5.253379223846905 1.0087059940177134
# New value of wo and bo:  5.260735739611093 1.0091146893379461
# New value of wo and bo:  5.302669662752917 1.0100898968528722
# New value of wo and bo:  5.35368137785465 1.0111752524933346
# New value of wo and bo:  5.377882651244679 1.011931542286773
# New value of wo and bo:  5.37810601862956 1.012005998081733
# New value of wo and bo:  5.418209903261936 1.0129841416093521
# New value of wo and bo:  5.425251737186437 1.0133983671343227
# New value of wo and bo:  5.430049106362721 1.0137410363612003
# New value of wo and bo:  5.431629437073702 1.013938577700073
# New value of wo and bo:  5.4582134813740755 1.0147441548000842
# New value of wo and bo:  5.515001797179238 1.0159272447126917
# New value of wo and bo:  5.5307995402227865 1.0165591544344337
# New value of wo and bo:  5.544260278396085 1.0171444039202293
# New value of wo and bo:  5.544260278396085 1.0171444039202293

# %%
# Chat GPT - Method :
import numpy as np
import random

# Step 1: Generate a random sample of 30 values in the range 1-40
random.seed(42)  # for reproducibility
x = np.array(random.sample(range(1, 41), 30))

# Step 2: Calculate y = 3*x + 0.7
y = 3 * x + 0.7

# Step 3: Initialize W0 and b0
W0 = 5  # initial weight
b0 = 1  # initial bias

# Learning rate
lr = 0.00001

# Function to compute the gradient descent updates in a single epoch
def gradient_descent_single_epoch(x, y, W0, b0, lr):
    n = len(x)
    for i in range(n):
        # Predicted y
        y_pred = W0 * x[i] + b0

        # Update W0 and b0 using the provided formulas
        W0 = W0 - lr * (y[i] - y_pred) * x[i]
        b0 = b0 - lr * (y[i] - y_pred)

    return W0, b0

# Step 4: Update the values of W0 and b0 using gradient descent for a single epoch
W0_updated, b0_updated = gradient_descent_single_epoch(x, y, W0, b0, lr)

# Step 5: New equation y_n = W0 * x + b0
print(f"Updated equation after a single epoch: y_n = {W0_updated:.2f} * x + {b0_updated:.2f}")
# Out:
# Updated equation after a single epoch: y_n = 5.37 * x + 1.01
